# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import librosa.display
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,OneHotEncoder
from opensoundscape.audio import Audio
from opensoundscape.spectrogram import Spectrogram
from PIL import Image
from sklearn.metrics import accuracy_score
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
enc = LabelEncoder()
mms = MinMaxScaler()
oh = OneHotEncoder()
sns.set_style('darkgrid')

# %%
file_paths = []

emotions_encoder = {

    '01': 'Neutral',
    '02': 'Calm',
    '03': 'Happy',
    '04': 'Sad',
    '05': 'Angry',
    '06': 'Fearful',
    '07': 'Disgust',
    '08': 'Surprised'

}

emotions = []

folder = '../ravdess-data'

for i in range(24):

    subfolder = f"Actor_{str(i+1).zfill(2)}"

    directory = os.path.join(folder, subfolder)

    for filename in os.listdir(directory):

        path_file = os.path.join(directory, filename)

        file_paths.append(path_file)

        emotions.append(emotions_encoder[(filename.split('-')[2])])

data = pd.DataFrame(np.c_[file_paths,emotions],columns=['Path','Emotion'],).sample(frac=1).reset_index(inplace=False).drop(columns='index')

data.head()
# Out:
#                                                 Path  Emotion
# 0  ../ravdess-data\Actor_23\03-01-06-01-02-01-23.wav  Fearful
# 1  ../ravdess-data\Actor_10\03-01-01-01-01-01-10.wav  Neutral
# 2  ../ravdess-data\Actor_02\03-01-06-02-01-02-02.wav  Fearful
# 3  ../ravdess-data\Actor_18\03-01-06-02-02-02-18.wav  Fearful
# 4  ../ravdess-data\Actor_01\03-01-03-02-01-02-01.wav    Happy

# %%
emotions
# Out:
# ['Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Disgust',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Surprised',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Neutral',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Calm',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Happy',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Sad',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Angry',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  'Fearful',
#  ...]

# %%
plt.figure("The counts of Each emotion category in Dataset",(15,10))

sns.countplot(x = data.Emotion)

plt.title("Frequency of Each emotion class",fontdict={'fontsize': 20})

plt.tight_layout()

plt.show()

# %%
def wavplot(path,figsize=(15,5)):

    aud, sr = librosa.load(path=path,duration=2.1,offset=0.6)

    plt.figure(figsize=figsize)

    plt.plot(aud)

    plt.tight_layout()

    plt.show()

def specplot(path,figsize=(15,5)):

    aud, sr = librosa.load(path=path,duration=2.1,offset=0.6)

    X = abs(librosa.stft(aud))

    db = librosa.amplitude_to_db(X)

    plt.figure(figsize=figsize)

    librosa.display.specshow(db,sr=sr)

    plt.savefig("y.png")

    plt.show()

# %%
wavplot(data.Path[1])

# %%
specplot(data.Path[1])

# %%
aud, sr = librosa.load(data.Path[929],duration=2.5,offset=0.6)

X = abs(librosa.stft(aud))

mel = librosa.feature.mfcc(y=aud)

Chroma = librosa.feature.chroma_stft(S=X,sr=sr)

Chr = np.argmax(Chroma,axis=0).tolist()

freq = np.zeros(12,dtype=int)

for i in range(12):

    freq[i] += Chr.count(i+1)

# %%
plt.figure(figsize=(30,5))

sns.heatmap(Chroma)

plt.show()

# %%
Chroma.shape
# Out:
# (12, 108)

# %%
class Augment():

    def __init__(self):

        pass

    def load(self,path):

        aud, sr = librosa.load(path=path)

        self.aud = aud

        self.sampling_rate = sr

    def noise(self,path):

        self.load(path)

        aud = self.aud
        
        noise_amp = 0.035*np.random.uniform()*np.amax(aud)
        
        aud = aud + noise_amp*np.random.normal(size=aud.shape[0])
        
        return aud

    def time_stretch(self,path, rate=0.6):

        self.load(path)

        aud = self.aud

        return librosa.effects.time_stretch(aud, rate)

    def time_roll(self,path):

        self.load(path)

        aud = self.aud

        shift_range = int(np.random.uniform(low=-5, high = 5)*1000)

        return np.roll(aud, shift_range)

    def pitch(self,path, pitch_factor=0.6):

        self.load(path)

        aud = self.aud

        sampling_rate = self.sampling_rate

        return librosa.effects.pitch_shift(aud, sampling_rate, pitch_factor)

    def get_methods(self,path,methods=[]):

        noised = []

        stretched = []

        rolled = []

        pitched = []

        for path in data.Path:

            noised.append(self.noise(path))

            stretched.append(self.time_stretch(path))

            rolled.append(self.time_roll(path))

            pitched.append(self.pitch(path))

        return noised,stretched,rolled,pitched


aug = Augment()

# %%
class Preprocess():

    def __init__(self,sr=None):

        self.sampling_rate = sr

    def load(self,path):

        aud,sr = librosa.load(path=path)

        self.sampling_rate = sr

        return aud

    def get_zcr(self,aud):

        Z = np.mean(librosa.feature.zero_crossing_rate(y=aud),axis=0)

        return Z

    def get_mfcc(self,aud):

        M = np.mean(librosa.feature.mfcc(y=aud, sr=self.sampling_rate, n_mfcc=40).T, axis=0)

        return M

    def get_mel(self,aud):

        Me = np.mean(librosa.feature.melspectrogram(y=aud,sr=self.sampling_rate).T, axis=0)

        return Me

    def get_chroma_freq(self,aud):

        X = abs(librosa.stft(aud))

        Chr = np.argmax(librosa.feature.chroma_stft(S=X,sr=self.sampling_rate), axis=0).tolist()

        freq = np.zeros(12,dtype=int)

        for i in range(12):

            freq[i] += Chr.count(i+1)

        return freq

    def get_chroma(self,aud):

        X = np.abs(librosa.stft(aud))

        Chr = librosa.feature.chroma_stft(S=X, sr=self.sampling_rate)

        return np.mean(Chr.T, 0)



    def get_meansquared(self,aud):

        me = np.sqrt(np.mean(aud**2))

        return me

    def get_spread(self,aud):

        var = np.var(aud)

        return var

    def extract_features(self, aud, features=['chroma', 'mel', 'mfcc']):
        chroma = self.get_chroma(aud)

        mel = self.get_mel(aud)

        mfcc = self.get_mfcc(aud)
        final_ftrs = []

        for f in features:
            final_ftrs.append(eval(f))

        return np.hstack(final_ftrs)

feat = Preprocess()

# %%
x1 = []

for path in data.Path:

    x1.append((feat.extract_features(feat.load(path))))

X = np.array(x1)

Y = enc.fit_transform(emotions).reshape(-1,1)

Yoh = oh.fit_transform(Y).toarray()

xtrain, xtest, ytrain, ytest = train_test_split(X, Y, shuffle=True, random_state=42, train_size=0.7)

yotrain,yotest = oh.transform(ytrain).toarray(),oh.transform(ytest).toarray()

# %%
mu = np.mean(xtrain, 0)
std = np.std(xtrain, 0)

xtrain = (xtrain - mu)/std
xtest = (xtest - mu)/std

# %% [markdown]
# ### Shallow MLP

# %%
from tensorflow.keras.layers import Dense,Conv2D,MaxPooling2D,InputLayer,BatchNormalization,Flatten,Dropout,Conv1D,MaxPooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.activations import relu,softmax
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
tf.config.run_functions_eagerly(True)

# %%
xtrain.shape
# Out:
# (1007, 160)

# %%
ytrain = to_categorical(ytrain)
ytest = to_categorical(ytest)

# %%
model = Sequential()
model.add(Dense(128, input_shape=(160,), activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(8, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              metrics=['accuracy'])

# %%
model.fit(xtrain, ytrain, validation_data=(xtest, ytest), epochs=100, batch_size=250, verbose=1)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 83ms/step - loss: 1.8770 - accuracy: 0.2949 - val_loss: 2.2350 - val_accuracy: 0.1270
# Epoch 2/100
# 5/5 [==============================] - 0s 63ms/step - loss: 1.8314 - accuracy: 0.3307 - val_loss: 2.2473 - val_accuracy: 0.1109
# Epoch 3/100
# 5/5 [==============================] - 0s 65ms/step - loss: 1.8179 - accuracy: 0.3386 - val_loss: 2.2754 - val_accuracy: 0.1109
# Epoch 4/100
# 5/5 [==============================] - 0s 68ms/step - loss: 1.8060 - accuracy: 0.3317 - val_loss: 2.3093 - val_accuracy: 0.1155
# Epoch 5/100
# 5/5 [==============================] - 0s 59ms/step - loss: 1.7957 - accuracy: 0.3237 - val_loss: 2.3163 - val_accuracy: 0.1132
# Epoch 6/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.7839 - accuracy: 0.3436 - val_loss: 2.3170 - val_accuracy: 0.1178
# Epoch 7/100
# 5/5 [==============================] - 0s 53ms/step - loss: 1.7670 - accuracy: 0.3625 - val_loss: 2.3203 - val_accuracy: 0.1363
# Epoch 8/100
# 5/5 [==============================] - 0s 58ms/step - loss: 1.7604 - accuracy: 0.3644 - val_loss: 2.3321 - val_accuracy: 0.1432
# Epoch 9/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.7543 - accuracy: 0.3466 - val_loss: 2.3414 - val_accuracy: 0.1247
# Epoch 10/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.7408 - accuracy: 0.3684 - val_loss: 2.3503 - val_accuracy: 0.1224
# Epoch 11/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.7301 - accuracy: 0.3853 - val_loss: 2.3679 - val_accuracy: 0.1039
# Epoch 12/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.7213 - accuracy: 0.3843 - val_loss: 2.3882 - val_accuracy: 0.0924
# Epoch 13/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.7188 - accuracy: 0.3913 - val_loss: 2.3943 - val_accuracy: 0.1109
# Epoch 14/100
# 5/5 [==============================] - 0s 56ms/step - loss: 1.7107 - accuracy: 0.3952 - val_loss: 2.4049 - val_accuracy: 0.1201
# Epoch 15/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.6960 - accuracy: 0.4081 - val_loss: 2.4347 - val_accuracy: 0.1155
# Epoch 16/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.6894 - accuracy: 0.4131 - val_loss: 2.4758 - val_accuracy: 0.1085
# Epoch 17/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.6748 - accuracy: 0.4111 - val_loss: 2.4657 - val_accuracy: 0.1016
# Epoch 18/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.6590 - accuracy: 0.4290 - val_loss: 2.4660 - val_accuracy: 0.0947
# Epoch 19/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.6512 - accuracy: 0.4320 - val_loss: 2.4815 - val_accuracy: 0.1132
# Epoch 20/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.6439 - accuracy: 0.4300 - val_loss: 2.5003 - val_accuracy: 0.1039
# Epoch 21/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.6409 - accuracy: 0.4250 - val_loss: 2.5233 - val_accuracy: 0.1085
# Epoch 22/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.6354 - accuracy: 0.4300 - val_loss: 2.5269 - val_accuracy: 0.1016
# Epoch 23/100
# 5/5 [==============================] - 0s 52ms/step - loss: 1.6256 - accuracy: 0.4340 - val_loss: 2.5369 - val_accuracy: 0.1039
# Epoch 24/100
# 5/5 [==============================] - 0s 54ms/step - loss: 1.6195 - accuracy: 0.4518 - val_loss: 2.5544 - val_accuracy: 0.1062
# Epoch 25/100
# 5/5 [==============================] - 0s 57ms/step - loss: 1.6048 - accuracy: 0.4508 - val_loss: 2.5623 - val_accuracy: 0.0878
# Epoch 26/100
# 5/5 [==============================] - 0s 62ms/step - loss: 1.5953 - accuracy: 0.4628 - val_loss: 2.5678 - val_accuracy: 0.0947
# Epoch 27/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.5891 - accuracy: 0.4578 - val_loss: 2.5858 - val_accuracy: 0.0924
# Epoch 28/100
# 5/5 [==============================] - 0s 63ms/step - loss: 1.5833 - accuracy: 0.4528 - val_loss: 2.6164 - val_accuracy: 0.0947
# Epoch 29/100
# 5/5 [==============================] - 0s 63ms/step - loss: 1.5789 - accuracy: 0.4568 - val_loss: 2.6585 - val_accuracy: 0.1155
# Epoch 30/100
# 5/5 [==============================] - 0s 58ms/step - loss: 1.5723 - accuracy: 0.4747 - val_loss: 2.6617 - val_accuracy: 0.1085
# Epoch 31/100
# 5/5 [==============================] - 0s 56ms/step - loss: 1.5626 - accuracy: 0.4935 - val_loss: 2.6464 - val_accuracy: 0.1155
# Epoch 32/100
# 5/5 [==============================] - 0s 54ms/step - loss: 1.5537 - accuracy: 0.4866 - val_loss: 2.6506 - val_accuracy: 0.1109
# Epoch 33/100
# 5/5 [==============================] - 0s 61ms/step - loss: 1.5433 - accuracy: 0.4836 - val_loss: 2.6545 - val_accuracy: 0.1062
# Epoch 34/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.5333 - accuracy: 0.4886 - val_loss: 2.6618 - val_accuracy: 0.1016
# Epoch 35/100
# 5/5 [==============================] - 0s 55ms/step - loss: 1.5216 - accuracy: 0.4926 - val_loss: 2.6659 - val_accuracy: 0.1039
# Epoch 36/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.5128 - accuracy: 0.5015 - val_loss: 2.6824 - val_accuracy: 0.1062
# Epoch 37/100
# 5/5 [==============================] - 0s 52ms/step - loss: 1.5027 - accuracy: 0.5104 - val_loss: 2.6921 - val_accuracy: 0.1109
# Epoch 38/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.4967 - accuracy: 0.5094 - val_loss: 2.7075 - val_accuracy: 0.0993
# Epoch 39/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.4963 - accuracy: 0.4836 - val_loss: 2.7329 - val_accuracy: 0.0947
# Epoch 40/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.4895 - accuracy: 0.4846 - val_loss: 2.7366 - val_accuracy: 0.1085
# Epoch 41/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.4708 - accuracy: 0.5134 - val_loss: 2.7412 - val_accuracy: 0.1062
# Epoch 42/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.4838 - accuracy: 0.5094 - val_loss: 2.7695 - val_accuracy: 0.1085
# Epoch 43/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.4798 - accuracy: 0.4846 - val_loss: 2.7702 - val_accuracy: 0.1132
# Epoch 44/100
# 5/5 [==============================] - 0s 60ms/step - loss: 1.4562 - accuracy: 0.5194 - val_loss: 2.8034 - val_accuracy: 0.1062
# Epoch 45/100
# 5/5 [==============================] - 0s 62ms/step - loss: 1.4662 - accuracy: 0.4995 - val_loss: 2.8176 - val_accuracy: 0.1085
# Epoch 46/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.4535 - accuracy: 0.4995 - val_loss: 2.8117 - val_accuracy: 0.1016
# Epoch 47/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.4351 - accuracy: 0.5323 - val_loss: 2.8247 - val_accuracy: 0.0993
# Epoch 48/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.4241 - accuracy: 0.5353 - val_loss: 2.8366 - val_accuracy: 0.1109
# Epoch 49/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.4154 - accuracy: 0.5392 - val_loss: 2.8595 - val_accuracy: 0.1132
# Epoch 50/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.4155 - accuracy: 0.5184 - val_loss: 2.8793 - val_accuracy: 0.1109
# Epoch 51/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.4039 - accuracy: 0.5402 - val_loss: 2.8986 - val_accuracy: 0.1085
# Epoch 52/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.3992 - accuracy: 0.5422 - val_loss: 2.9134 - val_accuracy: 0.1062
# Epoch 53/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.3946 - accuracy: 0.5462 - val_loss: 2.9241 - val_accuracy: 0.0993
# Epoch 54/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.3888 - accuracy: 0.5462 - val_loss: 2.9481 - val_accuracy: 0.1062
# Epoch 55/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.3861 - accuracy: 0.5353 - val_loss: 2.9591 - val_accuracy: 0.1085
# Epoch 56/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.3729 - accuracy: 0.5412 - val_loss: 2.9492 - val_accuracy: 0.1109
# Epoch 57/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.3643 - accuracy: 0.5561 - val_loss: 2.9615 - val_accuracy: 0.1016
# Epoch 58/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.3623 - accuracy: 0.5581 - val_loss: 2.9884 - val_accuracy: 0.1016
# Epoch 59/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.3511 - accuracy: 0.5571 - val_loss: 3.0153 - val_accuracy: 0.0924
# Epoch 60/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.3465 - accuracy: 0.5462 - val_loss: 3.0244 - val_accuracy: 0.0855
# Epoch 61/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.3401 - accuracy: 0.5561 - val_loss: 3.0396 - val_accuracy: 0.0947
# Epoch 62/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.3308 - accuracy: 0.5670 - val_loss: 3.0826 - val_accuracy: 0.0993
# Epoch 63/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.3312 - accuracy: 0.5511 - val_loss: 3.1186 - val_accuracy: 0.0947
# Epoch 64/100
# 5/5 [==============================] - 0s 52ms/step - loss: 1.3397 - accuracy: 0.5283 - val_loss: 3.0759 - val_accuracy: 0.0970
# Epoch 65/100
# 5/5 [==============================] - 0s 58ms/step - loss: 1.3255 - accuracy: 0.5611 - val_loss: 3.0519 - val_accuracy: 0.1016
# Epoch 66/100
# 5/5 [==============================] - 0s 51ms/step - loss: 1.3173 - accuracy: 0.5720 - val_loss: 3.0539 - val_accuracy: 0.0993
# Epoch 67/100
# 5/5 [==============================] - 0s 64ms/step - loss: 1.3092 - accuracy: 0.5601 - val_loss: 3.0534 - val_accuracy: 0.0947
# Epoch 68/100
# 5/5 [==============================] - 0s 62ms/step - loss: 1.2939 - accuracy: 0.5789 - val_loss: 3.0983 - val_accuracy: 0.0855
# Epoch 69/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.3006 - accuracy: 0.5551 - val_loss: 3.1559 - val_accuracy: 0.1062
# Epoch 70/100
# 5/5 [==============================] - 0s 65ms/step - loss: 1.3039 - accuracy: 0.5501 - val_loss: 3.1363 - val_accuracy: 0.0901
# Epoch 71/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.2749 - accuracy: 0.5799 - val_loss: 3.1173 - val_accuracy: 0.0924
# Epoch 72/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.2623 - accuracy: 0.5948 - val_loss: 3.1438 - val_accuracy: 0.0878
# Epoch 73/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.2669 - accuracy: 0.5929 - val_loss: 3.1869 - val_accuracy: 0.0901
# Epoch 74/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.2593 - accuracy: 0.5988 - val_loss: 3.1859 - val_accuracy: 0.0970
# Epoch 75/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.2471 - accuracy: 0.6048 - val_loss: 3.1864 - val_accuracy: 0.0993
# Epoch 76/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.2331 - accuracy: 0.6197 - val_loss: 3.1883 - val_accuracy: 0.1016
# Epoch 77/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.2290 - accuracy: 0.6226 - val_loss: 3.2070 - val_accuracy: 0.1062
# Epoch 78/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.2257 - accuracy: 0.6286 - val_loss: 3.2314 - val_accuracy: 0.1201
# Epoch 79/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.2198 - accuracy: 0.6286 - val_loss: 3.2508 - val_accuracy: 0.1062
# Epoch 80/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.2172 - accuracy: 0.6028 - val_loss: 3.2486 - val_accuracy: 0.1016
# Epoch 81/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.2156 - accuracy: 0.6147 - val_loss: 3.2488 - val_accuracy: 0.0947
# Epoch 82/100
# 5/5 [==============================] - 0s 28ms/step - loss: 1.2045 - accuracy: 0.6226 - val_loss: 3.2582 - val_accuracy: 0.0924
# Epoch 83/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.2025 - accuracy: 0.6266 - val_loss: 3.2448 - val_accuracy: 0.1016
# Epoch 84/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.1807 - accuracy: 0.6346 - val_loss: 3.2383 - val_accuracy: 0.0970
# Epoch 85/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.1730 - accuracy: 0.6405 - val_loss: 3.2761 - val_accuracy: 0.1085
# Epoch 86/100
# 5/5 [==============================] - 0s 28ms/step - loss: 1.1675 - accuracy: 0.6425 - val_loss: 3.2976 - val_accuracy: 0.1039
# Epoch 87/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.1616 - accuracy: 0.6445 - val_loss: 3.3130 - val_accuracy: 0.1039
# Epoch 88/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.1536 - accuracy: 0.6495 - val_loss: 3.3031 - val_accuracy: 0.0947
# Epoch 89/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.1392 - accuracy: 0.6693 - val_loss: 3.3035 - val_accuracy: 0.0993
# Epoch 90/100
# 5/5 [==============================] - 0s 64ms/step - loss: 1.1335 - accuracy: 0.6653 - val_loss: 3.3081 - val_accuracy: 0.1132
# Epoch 91/100
# 5/5 [==============================] - 0s 74ms/step - loss: 1.1303 - accuracy: 0.6574 - val_loss: 3.3243 - val_accuracy: 0.1155
# Epoch 92/100
# 5/5 [==============================] - 0s 61ms/step - loss: 1.1337 - accuracy: 0.6495 - val_loss: 3.3770 - val_accuracy: 0.1132
# Epoch 93/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.1327 - accuracy: 0.6326 - val_loss: 3.3967 - val_accuracy: 0.1201
# Epoch 94/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.1231 - accuracy: 0.6455 - val_loss: 3.4048 - val_accuracy: 0.1201
# Epoch 95/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.1134 - accuracy: 0.6514 - val_loss: 3.4182 - val_accuracy: 0.1201
# Epoch 96/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.1033 - accuracy: 0.6624 - val_loss: 3.3973 - val_accuracy: 0.1178
# Epoch 97/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.0930 - accuracy: 0.6852 - val_loss: 3.3980 - val_accuracy: 0.1132
# Epoch 98/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.0931 - accuracy: 0.6902 - val_loss: 3.4116 - val_accuracy: 0.1085
# Epoch 99/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.0835 - accuracy: 0.6832 - val_loss: 3.4664 - val_accuracy: 0.1039
# Epoch 100/100
# 5/5 [==============================] - 0s 25ms/step - loss: 1.0784 - accuracy: 0.6812 - val_loss: 3.4882 - val_accuracy: 0.1109

# %%
from sklearn.neural_network import MLPClassifier

model = MLPClassifier(alpha=0.01, batch_size=256, epsilon=1e-08, hidden_layer_sizes=(300,), learning_rate='adaptive', max_iter=500)

# %%
xtrain.shape
# Out:
# (1007, 180)

# %%
em = np.unique(emotions).tolist()
y_p = [em[ytrain.ravel()[i]] for i in range(len(ytrain))]

# %%
model.fit(xtrain, ytrain.ravel())
# Out:
# C:\Users\nakul\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(alpha=0.01, batch_size=256, hidden_layer_sizes=(300,),
#               learning_rate='adaptive', max_iter=500)

# %%
y_pred=model.predict(xtest)

accuracy=accuracy_score(y_true=ytest, y_pred=y_pred)
#DataFlair - Print the accuracy
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 11.32%

# %% [markdown]
# ### 1-D CNN

# %%
xtrain = xtrain.reshape(-1,91,1)
xtest = xtest.reshape(-1,91,1)

# %%
model = Sequential()

model.add(InputLayer(input_shape=(91,1)))

model.add(Conv1D(256,3,padding="same",activation=relu))

model.add(Conv1D(256,3,padding="same",activation=relu))

model.add(Dropout(0.25))

# model.add(BatchNormalization())

# model.add(MaxPooling1D(pool_size=4,strides=2))

# model.add(Conv1D(128,3,padding="same",activation=relu))

# model.add(Conv1D(128,3,padding="same",activation=relu))

# model.add(Dropout(0.25))

# model.add(BatchNormalization())

# model.add(MaxPooling1D(strides=2,pool_size=4))

# model.add(Conv1D(64,3,padding="same",activation=relu))

# model.add(Conv1D(64,3,padding="same",activation=relu))

# model.add(Dropout(0.25))

# model.add(BatchNormalization())

# model.add(MaxPooling1D(strides=2,pool_size=4))

model.add(Flatten())

model.add(Dropout(0.25))

model.add(Dense(32,activation=relu))

model.add(Dense(16,activation=relu))

model.add(Dense(8,activation=softmax))

model.compile(loss=categorical_crossentropy,optimizer=Adam(),metrics="accuracy")

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 91, 256)           1024
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 91, 256)           196864
# _________________________________________________________________
# dropout (Dropout)            (None, 91, 256)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 23296)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23296)             0
# _________________________________________________________________
# dense (Dense)                (None, 32)                745504
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# =================================================================
# Total params: 944,056
# Trainable params: 944,056
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x=xtrain,y=yotrain,epochs=100,validation_data=(xtest,yotest))
# Out:
# Epoch 1/100
#  2/32 [>.............................] - ETA: 1s - loss: 2.8273 - accuracy: 0.1719
# C:\Users\Aaditya Baranwal\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:3703: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable.debug_mode()`.
#   warnings.warn(
# 32/32 [==============================] - 2s 63ms/step - loss: 2.1809 - accuracy: 0.1291 - val_loss: 2.0695 - val_accuracy: 0.1570
# Epoch 2/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0773 - accuracy: 0.1331 - val_loss: 2.0541 - val_accuracy: 0.1570
# Epoch 3/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0711 - accuracy: 0.1301 - val_loss: 2.0653 - val_accuracy: 0.1409
# Epoch 4/100
# 32/32 [==============================] - 2s 64ms/step - loss: 2.0696 - accuracy: 0.1450 - val_loss: 2.0694 - val_accuracy: 0.1085
# Epoch 5/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0685 - accuracy: 0.1261 - val_loss: 2.0646 - val_accuracy: 0.1339
# Epoch 6/100
# 32/32 [==============================] - 2s 64ms/step - loss: 2.0702 - accuracy: 0.1291 - val_loss: 2.0638 - val_accuracy: 0.1085
# Epoch 7/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0649 - accuracy: 0.1360 - val_loss: 2.0597 - val_accuracy: 0.1293
# Epoch 8/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0649 - accuracy: 0.1321 - val_loss: 2.0695 - val_accuracy: 0.1316
# Epoch 9/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0681 - accuracy: 0.1281 - val_loss: 2.0634 - val_accuracy: 0.1293
# Epoch 10/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0654 - accuracy: 0.1301 - val_loss: 2.0622 - val_accuracy: 0.1109
# Epoch 11/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0703 - accuracy: 0.1360 - val_loss: 2.0782 - val_accuracy: 0.1085
# Epoch 12/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0641 - accuracy: 0.1430 - val_loss: 2.0680 - val_accuracy: 0.1085
# Epoch 13/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0643 - accuracy: 0.1430 - val_loss: 2.0635 - val_accuracy: 0.1062
# Epoch 14/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0606 - accuracy: 0.1490 - val_loss: 2.0645 - val_accuracy: 0.1085
# Epoch 15/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0567 - accuracy: 0.1380 - val_loss: 2.0618 - val_accuracy: 0.1062
# Epoch 16/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0579 - accuracy: 0.1549 - val_loss: 2.0604 - val_accuracy: 0.1132
# Epoch 17/100
# 32/32 [==============================] - 2s 64ms/step - loss: 2.0517 - accuracy: 0.1410 - val_loss: 2.0585 - val_accuracy: 0.1155
# Epoch 18/100
# 32/32 [==============================] - 2s 64ms/step - loss: 2.0514 - accuracy: 0.1549 - val_loss: 2.0655 - val_accuracy: 0.1109
# Epoch 19/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0427 - accuracy: 0.1559 - val_loss: 2.0605 - val_accuracy: 0.1085
# Epoch 20/100
# 32/32 [==============================] - 2s 64ms/step - loss: 2.0398 - accuracy: 0.1549 - val_loss: 2.0650 - val_accuracy: 0.1132
# Epoch 21/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0346 - accuracy: 0.1519 - val_loss: 2.0543 - val_accuracy: 0.1062
# Epoch 22/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0320 - accuracy: 0.1420 - val_loss: 2.0583 - val_accuracy: 0.1409
# Epoch 23/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0259 - accuracy: 0.1639 - val_loss: 2.0600 - val_accuracy: 0.1178
# Epoch 24/100
# 32/32 [==============================] - 2s 64ms/step - loss: 2.0222 - accuracy: 0.1470 - val_loss: 2.0528 - val_accuracy: 0.1432
# Epoch 25/100
# 32/32 [==============================] - 2s 64ms/step - loss: 2.0177 - accuracy: 0.1569 - val_loss: 2.0562 - val_accuracy: 0.1339
# Epoch 26/100
# 32/32 [==============================] - 2s 64ms/step - loss: 2.0191 - accuracy: 0.1748 - val_loss: 2.0614 - val_accuracy: 0.1293
# Epoch 27/100
# 32/32 [==============================] - 2s 63ms/step - loss: 2.0112 - accuracy: 0.1728 - val_loss: 2.0709 - val_accuracy: 0.1270
# Epoch 28/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.9877 - accuracy: 0.1857 - val_loss: 2.1087 - val_accuracy: 0.1386
# Epoch 29/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.9659 - accuracy: 0.1867 - val_loss: 2.1780 - val_accuracy: 0.1363
# Epoch 30/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.9748 - accuracy: 0.1837 - val_loss: 2.1030 - val_accuracy: 0.1270
# Epoch 31/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.9537 - accuracy: 0.1917 - val_loss: 2.1460 - val_accuracy: 0.1455
# Epoch 32/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.9269 - accuracy: 0.2016 - val_loss: 2.1481 - val_accuracy: 0.1224
# Epoch 33/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.9138 - accuracy: 0.2205 - val_loss: 2.2915 - val_accuracy: 0.1363
# Epoch 34/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.9218 - accuracy: 0.1996 - val_loss: 2.3352 - val_accuracy: 0.1062
# Epoch 35/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.9131 - accuracy: 0.2195 - val_loss: 2.2954 - val_accuracy: 0.1339
# Epoch 36/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.9064 - accuracy: 0.2234 - val_loss: 2.2600 - val_accuracy: 0.1293
# Epoch 37/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.8766 - accuracy: 0.2393 - val_loss: 2.2791 - val_accuracy: 0.1363
# Epoch 38/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.8809 - accuracy: 0.2502 - val_loss: 2.3172 - val_accuracy: 0.1224
# Epoch 39/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.8810 - accuracy: 0.2304 - val_loss: 2.2661 - val_accuracy: 0.1062
# Epoch 40/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.8540 - accuracy: 0.2483 - val_loss: 2.3209 - val_accuracy: 0.1547
# Epoch 41/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.8282 - accuracy: 0.2522 - val_loss: 2.3876 - val_accuracy: 0.1270
# Epoch 42/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.8523 - accuracy: 0.2642 - val_loss: 2.3632 - val_accuracy: 0.1316
# Epoch 43/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.8008 - accuracy: 0.2632 - val_loss: 2.3938 - val_accuracy: 0.1363
# Epoch 44/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.7969 - accuracy: 0.2771 - val_loss: 2.5873 - val_accuracy: 0.1501
# Epoch 45/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.8003 - accuracy: 0.2681 - val_loss: 2.3812 - val_accuracy: 0.1386
# Epoch 46/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.8033 - accuracy: 0.2910 - val_loss: 2.5285 - val_accuracy: 0.1270
# Epoch 47/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.7876 - accuracy: 0.2959 - val_loss: 2.5642 - val_accuracy: 0.1270
# Epoch 48/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.7274 - accuracy: 0.3108 - val_loss: 2.6405 - val_accuracy: 0.1386
# Epoch 49/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.7458 - accuracy: 0.3069 - val_loss: 2.5964 - val_accuracy: 0.1524
# Epoch 50/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.7210 - accuracy: 0.2999 - val_loss: 2.4426 - val_accuracy: 0.1386
# Epoch 51/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.7137 - accuracy: 0.3098 - val_loss: 2.5351 - val_accuracy: 0.1455
# Epoch 52/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.7134 - accuracy: 0.3376 - val_loss: 2.6997 - val_accuracy: 0.1363
# Epoch 53/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.6746 - accuracy: 0.3217 - val_loss: 2.5216 - val_accuracy: 0.1524
# Epoch 54/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.6929 - accuracy: 0.3277 - val_loss: 2.7555 - val_accuracy: 0.1363
# Epoch 55/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.6765 - accuracy: 0.3436 - val_loss: 2.9264 - val_accuracy: 0.1524
# Epoch 56/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.6652 - accuracy: 0.3366 - val_loss: 2.9727 - val_accuracy: 0.1178
# Epoch 57/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.6532 - accuracy: 0.3545 - val_loss: 2.7491 - val_accuracy: 0.1155
# Epoch 58/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.6097 - accuracy: 0.3625 - val_loss: 3.0599 - val_accuracy: 0.1409
# Epoch 59/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.6012 - accuracy: 0.3615 - val_loss: 3.4826 - val_accuracy: 0.1247
# Epoch 60/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.6141 - accuracy: 0.3555 - val_loss: 2.9233 - val_accuracy: 0.1270
# Epoch 61/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.5899 - accuracy: 0.3744 - val_loss: 3.2015 - val_accuracy: 0.1316
# Epoch 62/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.5438 - accuracy: 0.3972 - val_loss: 3.1734 - val_accuracy: 0.1270
# Epoch 63/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.5628 - accuracy: 0.3813 - val_loss: 3.2399 - val_accuracy: 0.1270
# Epoch 64/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.5431 - accuracy: 0.3843 - val_loss: 3.0994 - val_accuracy: 0.1363
# Epoch 65/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.5162 - accuracy: 0.4101 - val_loss: 3.2876 - val_accuracy: 0.1085
# Epoch 66/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.5318 - accuracy: 0.3942 - val_loss: 3.3377 - val_accuracy: 0.1316
# Epoch 67/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.5113 - accuracy: 0.4121 - val_loss: 3.2779 - val_accuracy: 0.1339
# Epoch 68/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.4753 - accuracy: 0.4211 - val_loss: 3.2934 - val_accuracy: 0.1478
# Epoch 69/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.4786 - accuracy: 0.4062 - val_loss: 3.1978 - val_accuracy: 0.1293
# Epoch 70/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.4627 - accuracy: 0.4280 - val_loss: 3.2929 - val_accuracy: 0.1085
# Epoch 71/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.4544 - accuracy: 0.4320 - val_loss: 3.3819 - val_accuracy: 0.1132
# Epoch 72/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.4016 - accuracy: 0.4578 - val_loss: 3.4220 - val_accuracy: 0.1109
# Epoch 73/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.4047 - accuracy: 0.4598 - val_loss: 3.8023 - val_accuracy: 0.1247
# Epoch 74/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.3908 - accuracy: 0.4548 - val_loss: 3.4722 - val_accuracy: 0.1132
# Epoch 75/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.3827 - accuracy: 0.4558 - val_loss: 3.4869 - val_accuracy: 0.1386
# Epoch 76/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.3620 - accuracy: 0.4727 - val_loss: 3.6186 - val_accuracy: 0.1432
# Epoch 77/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.3748 - accuracy: 0.4459 - val_loss: 3.5020 - val_accuracy: 0.1339
# Epoch 78/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.3319 - accuracy: 0.4886 - val_loss: 3.9849 - val_accuracy: 0.1316
# Epoch 79/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.3375 - accuracy: 0.4965 - val_loss: 3.8842 - val_accuracy: 0.1363
# Epoch 80/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.3484 - accuracy: 0.4916 - val_loss: 4.1169 - val_accuracy: 0.1247
# Epoch 81/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.3312 - accuracy: 0.4926 - val_loss: 3.6853 - val_accuracy: 0.1247
# Epoch 82/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.3409 - accuracy: 0.4896 - val_loss: 3.9221 - val_accuracy: 0.1316
# Epoch 83/100
# 32/32 [==============================] - 2s 66ms/step - loss: 1.2783 - accuracy: 0.5233 - val_loss: 4.1876 - val_accuracy: 0.1478
# Epoch 84/100
# 32/32 [==============================] - 2s 68ms/step - loss: 1.2662 - accuracy: 0.5144 - val_loss: 4.1150 - val_accuracy: 0.1455
# Epoch 85/100
# 32/32 [==============================] - 2s 66ms/step - loss: 1.2254 - accuracy: 0.5422 - val_loss: 3.7235 - val_accuracy: 0.1178
# Epoch 86/100
# 32/32 [==============================] - 2s 67ms/step - loss: 1.2408 - accuracy: 0.5233 - val_loss: 4.0876 - val_accuracy: 0.1293
# Epoch 87/100
# 32/32 [==============================] - 2s 67ms/step - loss: 1.1973 - accuracy: 0.5402 - val_loss: 4.2436 - val_accuracy: 0.1132
# Epoch 88/100
# 32/32 [==============================] - 2s 66ms/step - loss: 1.1952 - accuracy: 0.5462 - val_loss: 4.3711 - val_accuracy: 0.1316
# Epoch 89/100
# 32/32 [==============================] - 2s 66ms/step - loss: 1.1392 - accuracy: 0.5670 - val_loss: 4.4580 - val_accuracy: 0.1363
# Epoch 90/100
# 32/32 [==============================] - 2s 66ms/step - loss: 1.1692 - accuracy: 0.5591 - val_loss: 4.4154 - val_accuracy: 0.1270
# Epoch 91/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.1970 - accuracy: 0.5303 - val_loss: 4.4506 - val_accuracy: 0.1386
# Epoch 92/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.1452 - accuracy: 0.5611 - val_loss: 4.6277 - val_accuracy: 0.1363
# Epoch 93/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.1212 - accuracy: 0.5730 - val_loss: 4.2216 - val_accuracy: 0.1224
# Epoch 94/100
# 32/32 [==============================] - 2s 63ms/step - loss: 1.1414 - accuracy: 0.5700 - val_loss: 5.0370 - val_accuracy: 0.1293
# Epoch 95/100
# 32/32 [==============================] - 2s 64ms/step - loss: 1.1017 - accuracy: 0.5740 - val_loss: 4.8718 - val_accuracy: 0.1316
# Epoch 96/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.0987 - accuracy: 0.5948 - val_loss: 5.0263 - val_accuracy: 0.1201
# Epoch 97/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.0928 - accuracy: 0.5819 - val_loss: 5.0041 - val_accuracy: 0.1409
# Epoch 98/100
# 32/32 [==============================] - 2s 68ms/step - loss: 1.1081 - accuracy: 0.5750 - val_loss: 4.9655 - val_accuracy: 0.1155
# Epoch 99/100
# 32/32 [==============================] - 2s 69ms/step - loss: 1.0695 - accuracy: 0.5730 - val_loss: 5.4605 - val_accuracy: 0.1270
# Epoch 100/100
# 32/32 [==============================] - 2s 65ms/step - loss: 1.0475 - accuracy: 0.6008 - val_loss: 4.9224 - val_accuracy: 0.1386

# %%
from lightgbm import LGBMClassifier
lgm = LGBMClassifier()

# %%
lgm.fit(xtrain,ytrain)
# Out:
# C:\Users\Aaditya Baranwal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Aaditya Baranwal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LGBMClassifier()

# %%
res = lgm.predict(xtest)

# %%
accuracy_score(res,ytest.ravel())
# Out:
# 0.13856812933025403
